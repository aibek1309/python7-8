# %% [markdown]
# <sup> Информатика, 7 химический класс, 2017 год. Python - 7 </sup>
# # 8. Игра "Крестики-нолики"

# %% [markdown]
# Применим всё, что мы знаем, чтобы реализовать простую игру в командной строке. Конечная цель нашего путешествия -- написать программу с такой функциональностью:
#
# 0. Сначала программа принимает на вход два числа $m, n$ -- ширину и высоту игрового поля, и третье число $k$ -- сколько фигурок нужно поставить в ряд, чтобы выиграть.
# 1. Далее программа поочерёдно выводит "Ход крестика" или "Ход нолика". После каждого такого запроса пользователь вводит два числа через пробел. Программа печатает игровое поле с новой фигуркой.
# 2. Если после какого-то хода условие победы выполнено, то программа завершается и выводит "Победил крестик" или "Победил нолик".
# 3. Если после какого-то хода поле заполнено целиком, а условие победы не выполнено, наступила ничья -- тогда программа выводит "Ничья".

# %% [markdown]
# Решение этой большой задачи будет разбито на последовательность простых задач. Начнём с небольшой теоретической подготовки. Перед написанием большой программы всегда хорошо проанализировать алгоритм и разобраться в нём, разложить на маленькие задачки.

# %% [markdown]
# ## Задание 1. Блок-схема
# Нарисуйте блок-схему алгоритма. Команды должны быть записаны в прямоугольниках, а условия в ромбах.  Загрузите картинку куда угодно в интернет, например, в ВКонтакте, и получите оттуда ссылку на неё. Вставьте ссылку на картинку в код ниже.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "ссылка на картинку")
# Out:
# <img src="ссылка на картинку"/>

# %% [markdown]
# ## Задание 2. Анализ условий конца игры
# Сформулируйте в одном предложении (может быть,содержащем логические операторы И, ИЛИ, НЕ, переменные $m, n, k$) условие победы какой-либо стороны. Подсказка: сколько ходов нужно сделать, чтобы место на поле точно закончилось? Когда закончится игра, если место на поле ещё есть?

# %% [markdown]
# *Ответ:*

# %% [markdown]
# ## Задание 3. Хранение поля
# Очевидно, чтобы проверять разные условия конца игры, нам потребуется игровое поле. Простой вариант для хранения поля -- двумерный массив. Двумерный массив представляет собой по сути массив массивов. Например, чтобы сделать массив из нулей размера 2х3, можно написать:
#
#     ar1 = [[0, 0, 0], [0, 0, 0]]
#
# Однако у нас размеры поля задаются с клавиатуры. Вот пример конструкции, которая создаёт массив из нулей размера 2х3.
#
#     ar2 = [ [0] * 3 for _ in range(2) ]
#
# Можно пока не разбираться в том, что происходит в такой конструкции. Ваша задача: написать функцию, которая ничего не принимает на вход, считывает с клавиатуры числа m, n, k и возвращает созданное поле из нулей и значение переменной k. Функция должна называться read_game_info()

# %%
def read_game_info():
    #считайте три числовые переменные с клавиатуры: m, n, k
    #создайте поле размера m x n, назовите переменную read_field
    return read_field, k

# %% [markdown]
# Теперь когда мы захотим начать игру, мы можем написать так:
#
#     field, k = read_game_info()
#
# И наши переменные field и k проиницализируются тем, что мы хотим!

# %% [markdown]
# ## Задание 4. Ход крестика
#
# Основная часть игры состоит из последовательности поочерёдных ходов. Логично эту последовательность реализовать в цикле, но что будет в теле цикла? В теле цикла мы будем вызывать функцию хода. Её мы сейчас и напишем.
#
# Что вообще случается за ход? Сначала считываются две переменные -- координаты хода на поле. Дальше нужно в массив field записать, в какую клетку сделан ход, а затем красиво вывести этот массив на экран. Ещё надо проверить, можно ли такой ход вообще делать.
#
# Наш массив заполнен нулями. Удобно считать, что крестики в массиве будут единицами, а нолики -- минус единицами. Сперва напишем функцию, которая делает ход крестика. Назовём её make_cross_turn().
#
# Что функция должна принимать на вход? Конечно, ей понадобится поле игры. Она также вернёт поле игры, потому что эта переменная внутри функции будет удалена, а нам нужно хранить её в течение всей игры.

# %%
def print_field(field): #эта функция отвечает за распечатку поля
    for row in field:
        print("|", end="")
        for char in row:
            if char == 1:
                print("X", end='|')
            elif char == -1:
                print("O", end='|')
            else:
                print("_", end='|')
        print()
    
def make_cross_turn(field): #вернёт True, если ход произошёл, False иначе
    print("Ход крестика")
    #считайте переменные x и y -- координаты хода.
    if True: #вместо true впишите условие того, что в эту клетку действительно можно сделать ход.
        field[x][y] = 1 #записали в field информацию о том, что на вход подан крестик
    else:
        print("Вы сделали ошибочный ход!")
        return False, field
    print_field(field)
    return True, field

# %% [markdown]
# ## Задание 5. Ваш ход!
# В предыдущем задании вы немного отредактировали код функции make_cross_turn(), чтобы эта функция делала корректный ход крестиком. Настало время усложнить эту функцию.
#
# Напишите новую функцию make_turn(). Эта функция должна делать ход либо крестика, либо нолика, в зависимости от чётности номера хода. Для этого ей нужно знать номер хода -- передайте его, как аргумент функции. Внимательно посмотрите на код функции make_cross_turn() и поймите, что в ней нужно заменить, чтобы она работала не только для крестика.

# %%
def make_turn(field, n):
    #ваш код!
    return

# %% [markdown]
# ## Задание 6. Проверка условий конца игры
#
# В задании 2 вы сформулировали, какие есть условия того, что игра закончилась. Настало время объединить эти условия в одну функцию.
#
# Напишите функцию check_winner(). Она должна вернуть 1, если игра на таком поле завершена и победил крестик, -1, если игра завершена и победил нолик, 0 если игра завершена вничью и None, если игра ещё не завершилась (напоминание: None отличается от истины и лжи). В качестве аргумента функция принимает игровое поле.

# %%
def check_winner(field):
    #ваш код
    return

# %% [markdown]
# ## Задание 7. Модульное тестирование
#
# Настало время понять, зачем мы написали столько функций.
#
# В программах бывают ошибки. Точнее, во всех программах есть ошибки. Но их количество можно уменьшить несложными способами.
#
# Один из таких способов -- модульное тестирование кода. Давайте перед тем, как собирать наш звездолёт воедино, проверим отдельно, работает ли мотор, надёжен ли корпус и как у корабля с системой навигации. В нашем случае всеми этими составными частями будут те функции, что мы написали раньше.
#
# Проверьте, что все функции, написанные выше, работают как надо.
#
# ### Пример проверки
#
#     test_field = [[1, 1, 1], [0, 0, 0], [0, 0, 0]] # поле 3х3 с тремя крестиками
#     if check_winner(test_field) == 1: # запускаем функцию проверки победителя и убеждаемся, что она выдаёт крестик
#         print("OK")
#     else:
#         print("Test 1 failed")
#
# Для проверки напишите от 3 до 5 тестов для каждой функции. Эти тесты обязательно должны включать крайние случаи (пустое поле или некорректный ход, например). Протестируйте функции *check_winner*, *make_turn*, *read_game_info*.
#
# Когда обнаружите ошибки в тех функциях, что вы написали выше, исправьте их. Напишите ниже список багов, которых вы нашли, и как вы их исправили (кратко).

# %%
# ваши тесты

# %% [markdown]
# ### Найденные баги
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## Задание 8. Собираем всё воедино

# %% [markdown]
# Теперь, когда все отдельные части кода протестированы, остаётся собрать всё вместе.
# Посмотрите на блок-схему, которую нарисовали в начале. В ней есть блок входа, затем следует цикл ходов с проверкой условий. Обратите внимание, что make_turn возвращает пару из булевой переменной и поля. Это значит, что внутри цикла ходов часть кода будет устроена так:
#
#     success, field = make_turn(field, num_turns)
#     if success:
#         num_turns += 1
#
# Это позволит увеличивать число ходов, только если ход был успешен.
# Какое будет условие выхода из цикла? Конечно, условие, что победитель нашёлся.
#
# Реализуйте основной цикл игры (также добавьте функцию, которая инициализирует игру). Оформите его в виде функции play_tic_tac_toe()

# %%
# ваш код

# %% [markdown]
# ## Задание 9. Вы думали, что тесты закончились?
#
# А вот и нет. Сыграйте несколько игр с кем-нибудь (3-5). Запускайте игры в разных ячейках ниже. Убедитесь, что всё работает.

# %%
play_tic_tac_toe()

# %%
play_tic_tac_toe()

# %%
play_tic_tac_toe()

# %% [markdown]
# ## Задание 10. Рефлексия
# <sup> Рефле́ксия (от позднелат. reflexio — обращение назад) — это обращение внимания субъекта на самого себя и на своё сознание, в частности, на продукты собственной активности, а также какое-либо их переосмысление. *Википедия* </sup>

# %% [markdown]
# **Вопрос 1**. Какие из перечисленных изменений легко сделать, а какие нет, и почему? Напишите не менее одного предложения по каждому пункту.
#
# 1. Добавить ещё один значок, чтобы можно было играть в "крестик, нолик, звёздочка".
# 2. Сделать игру на трёхмерном поле.
# 3. Сделать так, чтобы не было ничьих: если поле заполнено, то выиграл крестик (или нолик).
#
# *Ответ:*
#
# **Вопрос 2**. Как бы вы улучшили игру, которую написали? Напишите не менее трёх развёрнутых предложений.
#
# *Ответ:*
