# %% [markdown]
# <sup> Информатика, 7 химический класс, 2017 год. Python - 12 </sup>
# # 12. Tic Tac Toe revisited

# %% [markdown]
# В этот раз наша цель -- добавить графику с помощью matplotlib к крестикам-ноликам.

# %% [markdown]
# Ноутбуки можно сохранять как питоновские файлы. Для этого нужно нажать на кнопку File -> Download as -> Python file

# %% [markdown]
# Мы хотим весь код, написанный ранее для крестиков-ноликов, использовать в этом файле. Для этого сохраните ваш старый ноутбук как питоновский скрипт и положите его в папку с этим ноутбуком. Пусть он называется `tic_tac_toe.py`

# %%
# запустите этот код
import tic_tac_toe

# %% [markdown]
# Теперь вы все функции, которые написали в том файле, можете запускать в этом. Обратите внимание, что при импортировании весь файл выполнится. Возможно, вам придётся его сначала отредактировать, чтобы там остались только функции, а сам файл ничего не делал.

# %% [markdown]
# Теперь перейдём непосредственно к графике. Вам нужно будет сделать так, чтобы при каждом ходе отрисовывалось поле в виде matplotlib-графика. Так как мы изучали довольно мало возможностей библиотеки, вам придётся найти, как работают некоторые функции. Для этого вам поможет документация.

# %% [markdown]
# ## Задание 1
#
# Воспользуйтесь ссылками и найдите по ним или просто в интернете информацию о том, как сделать следующие вещи. Вам могут помочь примеры и документация. Составьте таблицу.

# %% [markdown]
#     1. https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter
#     2. https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot
#     3. добавьте сюда ссылки сами
#
# ### Некоторые возможности matplotlib
#
# |Что может понадобиться|Как это сделать|
# |---|---|
# |Делать так, чтобы scatter ставил не точку, а произвольный маркер (например, крестик)|---|
# |Менять прозрачность линий в plot|---|
# |Убрать координатные оси|---|
# |Сделать сетку (grid)|---|

# %% [markdown]
# ## Задание 2. Отрисовка поля
# Напишите функцию, которая принимает поле (такое же, как в задании про крестики-нолики) и с помощью matplotlib красиво его отрисовывает. Как конкретно рисовать поле и точки на нём -- на ваше усмотрение. Например, можно сделать автоматическую сетку и с помощью двух вызовов scatter нарисовать отдельно крестики и отдельно нолики.

# %% [markdown]
# ## Задание 3. Крестики-нолики с графикой
# Воспользуйтесь функциями из файла с реализацией крестиков-ноликов, чтобы добавить отрисовку поля после каждого хода. Закончите все задания из ноутбука по крестикам-ноликам.
